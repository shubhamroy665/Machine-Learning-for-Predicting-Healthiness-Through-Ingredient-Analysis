# %%
import pandas as pd
df=pd.read_csv('data.csv')
df
# Out:
#       NDB_No           Short_Description  Water_In_Grams  \
# 0       1001            BUTTER,WITH SALT           15.87
# 1       1002      BUTTER,WHIPPED,W/ SALT           16.72
# 2       1003        BUTTER OIL,ANHYDROUS            0.24
# 3       1004                 CHEESE,BLUE           42.41
# 4       1005                CHEESE,BRICK           41.11
# ...      ...                         ...             ...
# 8785   83110             MACKEREL,SALTED           43.00
# 8786   90240  SCALLOP,(BAY&SEA),CKD,STMD           70.25
# 8787   90480                  SYRUP,CANE           26.00
# 8788   90560                   SNAIL,RAW           79.20
# 8789   93600            TURTLE,GREEN,RAW           78.50
#
#       Energy_In_Kilogram_Calorie  Protein_In_Grams  Lipid_Tot_In_Grams  \
# 0                            717              0.85               81.11
# 1                            718              0.49               78.30
# ...

# %%
df.columns
# Out:
# Index(['NDB_No', 'Short_Description', 'Water_In_Grams',
#        'Energy_In_Kilogram_Calorie', 'Protein_In_Grams', 'Lipid_Tot_In_Grams',
#        'Ash_In_Grams', 'Carbohydrate_In_Grams', 'Fiber_TD_In_Grams',
#        'Sugar_Tot_In_Grams', 'Calcium_In_Miligrams', 'Iron_In_Miligrams',
#        'Magnesium_In_Miligrams', 'Phosphorus_In_Miligrams',
#        'Potassium_In_Miligrams', 'Sodium_In_Miligrams', 'Zinc_In_Miligrams',
#        'Copper_In_Miligrams', 'Manganese_In_Miligrams',
#        'Selenium_In_Micrograms', 'Vit_C_In_Miligrams', 'Thiamin_In_Miligrams',
#        'Riboflavin_In_Miligrams', 'Niacin_In_Miligrams',
#        'Panto_Acid_In_Miligrams', 'Vit_B6_In_Miligrams',
#        'Folate_Tot_In_Micrograms', 'Folic_Acid_In_Micrograms',
#        'Food_Folate_In_Micrograms', 'Folate_DFE_In_Micrograms',
#        'Choline_Tot_In_Miligrams', 'Vit_B12_In_Micrograms',
#        'Vit_A_In_International_Unit', 'Vit_A_In_Retinol_Activity_Equivalents',
# ...

# %%
df1 = df.drop(['NDB_No','Water_In_Grams','Ash_In_Grams','Calcium_In_Miligrams','Magnesium_In_Miligrams','Phosphorus_In_Miligrams','Potassium_In_Miligrams','Zinc_In_Miligrams','Copper_In_Miligrams', 'Manganese_In_Miligrams',
       'Selenium_In_Micrograms', 'Vit_C_In_Miligrams', 'Thiamin_In_Miligrams',
       'Riboflavin_In_Miligrams', 'Niacin_In_Miligrams',
       'Panto_Acid_In_Miligrams', 'Vit_B6_In_Miligrams',
       'Folate_Tot_In_Micrograms', 'Folic_Acid_In_Micrograms',
       'Food_Folate_In_Micrograms', 'Folate_DFE_In_Micrograms',
       'Choline_Tot_In_Miligrams', 'Vit_B12_In_Micrograms',
       'Vit_A_In_International_Unit', 'Vit_A_In_Retinol_Activity_Equivalents',
       'Retinol_In_Micrograms', 'Alpha_Carot_In_Micrograms',
       'Beta_Carot_In_Micrograms', 'Beta_Crypt_In_Micrograms',
       'Lycopene_In_Micrograms', 'Lut_And_Zea_In_Micrograms',
       'Vit_E_In_Miligrams', 'Vit_D_In_Micrograms',
       'Vit_D_In_International_Unit', 'Vit_K_In_Micrograms','FA_Mono_In_Grams', 'FA_Poly_In_Grams','Gram_Weight_1', 'Gram_Weight_Descritpion_1', 'Gram_Weight_2',
       'Gram_Weight_Description_2', 'Refuse_Percent'],axis = 1)
df1
# Out:
#                Short_Description  Energy_In_Kilogram_Calorie  \
# 0               BUTTER,WITH SALT                         717
# 1         BUTTER,WHIPPED,W/ SALT                         718
# 2           BUTTER OIL,ANHYDROUS                         876
# 3                    CHEESE,BLUE                         353
# 4                   CHEESE,BRICK                         371
# ...                          ...                         ...
# 8785             MACKEREL,SALTED                         305
# 8786  SCALLOP,(BAY&SEA),CKD,STMD                         111
# 8787                  SYRUP,CANE                         269
# 8788                   SNAIL,RAW                          90
# 8789            TURTLE,GREEN,RAW                          89
#
#       Protein_In_Grams  Lipid_Tot_In_Grams  Carbohydrate_In_Grams  \
# 0                 0.85               81.11                   0.06
# 1                 0.49               78.30                   2.87
# ...

# %%
df1['Added  Sugar(g) per 100 g'] = [0]* len(df1)
df1['trans fat (g) _per 100 g'] = [0]* len(df1)
df1.to_csv('real_data.csv')

# %%
x=pd.read_csv('real_data1.csv')
A=x.drop(['Unnamed: 0'] ,axis=1)
B=pd.read_csv('final_data.csv')
B=B.drop(['Unnamed: 0'], axis=1)
columns_order = B.columns

# Reorder the columns of df2 to match the order of df1's columns
A= A.reindex(columns=columns_order)
A
# Out:
#                        Food_name  Energy(kcal)_per 100 g  \
# 0               BUTTER,WITH SALT                     717
# 1         BUTTER,WHIPPED,W/ SALT                     718
# 2           BUTTER OIL,ANHYDROUS                     876
# 3                    CHEESE,BLUE                     353
# 4                   CHEESE,BRICK                     371
# ...                          ...                     ...
# 8785             MACKEREL,SALTED                     305
# 8786  SCALLOP,(BAY&SEA),CKD,STMD                     111
# 8787                  SYRUP,CANE                     269
# 8788                   SNAIL,RAW                      90
# 8789            TURTLE,GREEN,RAW                      89
#
#       Protein(g) per 100 g  Carbohydrate(g) per 100 g  \
# 0                     0.85                       0.06
# 1                     0.49                       2.87
# 2                     0.28                       0.00
# 3                    21.40                       2.34
# ...

# %%
len(A.columns)
# Out:
# 13

# %%
B.columns
# Out:
# Index(['Food_name', 'Energy(kcal)_per 100 g', 'Protein(g) per 100 g',
#        'Carbohydrate(g) per 100 g', 'total sugar(g) per 100 g',
#        'Added  Sugar(g) per 100 g', 'fibre(g) per 100 g',
#        'total fat (g) per 100 gms', 'saturated fat (g) per 100 g',
#        'trans fat (g) _per 100 g', 'Sodium(mg) per 100 g',
#        'iron (mg) per 100 gm', 'Cholesterol per 100 mg'],
#       dtype='object')

# %%
len(B.columns)
# Out:
# 13

# %%
import pandas as pd

# Assuming df1 and df3 are your DataFrames

# Concatenate df1 and df3 along the row axis
C = pd.concat([A, B], axis=0)

# Now concatenated_df contains both DataFrames stacked vertically
C.to_csv('my_data.csv')
